# %%
import pandas as pd
import os
import sys
import numpy as np
from scipy import sparse
import bottleneck as bn

# %% [markdown]
# # Data Preparation - Preprocessing
#
# **Note that only ML-20M dataset will be used. For other datasets please refer to the [paper](https://arxiv.org/pdf/1906.04281.pdf).**
#
# For fair comparison between performances, preprocessing is kept same with the one used in the paper. The same preprocessing steps were used in [Variational Autoencoders for Collaborative Filtering](https://arxiv.org/abs/1802.05814).
#
# The code below is taken from [this repository](https://github.com/dawenl/vae_cf). This repository contains the implementation of the methods proposed in Variational Autoencoders for Collaborative Filtering, Liang et. al.
#
# Please refer to the paper and the original repository for commentary on Preprocessing steps.
#
#
# First, download the dataset at http://files.grouplens.org/datasets/movielens/ml-20m.zip and extract in ./ml-20m directory.

# %%
DATA_DIR = './ml-20m/'
raw_data = pd.read_csv(os.path.join(DATA_DIR, 'ratings.csv'), header=0)

# %%
#  binarize the data (only keep ratings >= 4)
raw_data = raw_data[raw_data['rating'] > 3.5]

# %%
raw_data.head()
# Out:
#     userId  movieId  rating   timestamp
# 6        1      151     4.0  1094785734
# 7        1      223     4.0  1112485573
# 8        1      253     4.0  1112484940
# 9        1      260     4.0  1112484826
# 10       1      293     4.0  1112484703

# %%
def get_count(tp, id):
    playcount_groupbyid = tp[[id]].groupby(id, as_index=False)
    count = playcount_groupbyid.size()
    return count

def filter_triplets(tp, min_uc=5, min_sc=0):
    # Only keep the triplets for items which were clicked on by at least min_sc users. 
    if min_sc > 0:
        itemcount = get_count(tp, 'movieId')
        tp = tp[tp['movieId'].isin(itemcount.index[itemcount >= min_sc])]
    
    # Only keep the triplets for users who clicked on at least min_uc items
    # After doing this, some of the items will have less than min_uc users, but should only be a small proportion
    if min_uc > 0:
        usercount = get_count(tp, 'userId')
        tp = tp[tp['userId'].isin(usercount.index[usercount >= min_uc])]
    
    # Update both usercount and itemcount after filtering
    usercount, itemcount = get_count(tp, 'userId'), get_count(tp, 'movieId') 
    return tp, usercount, itemcount

# %%
raw_data, user_activity, item_popularity = filter_triplets(raw_data)

# %%
sparsity = 1. * raw_data.shape[0] / (user_activity.shape[0] * item_popularity.shape[0])

print("After filtering, there are %d watching events from %d users and %d movies (sparsity: %.3f%%)" % 
      (raw_data.shape[0], user_activity.shape[0], item_popularity.shape[0], sparsity * 100))
# Out:
# After filtering, there are 9990682 watching events from 136677 users and 20720 movies (sparsity: 0.353%)

# %%
unique_uid = user_activity.index

np.random.seed(98765)
idx_perm = np.random.permutation(unique_uid.size)
unique_uid = unique_uid[idx_perm]

# %%
# create train/validation/test users
n_users = unique_uid.size
n_heldout_users = 10000

tr_users = unique_uid[:(n_users - n_heldout_users * 2)]
vd_users = unique_uid[(n_users - n_heldout_users * 2): (n_users - n_heldout_users)]
te_users = unique_uid[(n_users - n_heldout_users):]

# %%
train_plays = raw_data.loc[raw_data['userId'].isin(tr_users)]

unique_sid = pd.unique(train_plays['movieId'])
show2id = dict((sid, i) for (i, sid) in enumerate(unique_sid))
profile2id = dict((pid, i) for (i, pid) in enumerate(unique_uid))

# %%
pro_dir = os.path.join(DATA_DIR, 'pro_sg')

if not os.path.exists(pro_dir):
    os.makedirs(pro_dir)

with open(os.path.join(pro_dir, 'unique_sid.txt'), 'w') as f:
    for sid in unique_sid:
        f.write('%s\n' % sid)

# %%
def split_train_test_proportion(data, test_prop=0.2):
    data_grouped_by_user = data.groupby('userId')
    tr_list, te_list = list(), list()

    np.random.seed(98765)

    for i, (_, group) in enumerate(data_grouped_by_user):
        n_items_u = len(group)

        if n_items_u >= 5:
            idx = np.zeros(n_items_u, dtype='bool')
            idx[np.random.choice(n_items_u, size=int(test_prop * n_items_u), replace=False).astype('int64')] = True

            tr_list.append(group[np.logical_not(idx)])
            te_list.append(group[idx])
        else:
            tr_list.append(group)

        if i % 1000 == 0:
            print("%d users sampled" % i)
            sys.stdout.flush()

    data_tr = pd.concat(tr_list)
    data_te = pd.concat(te_list)
    
    return data_tr, data_te
vad_plays = raw_data.loc[raw_data['userId'].isin(vd_users)]
vad_plays = vad_plays.loc[vad_plays['movieId'].isin(unique_sid)]

# %%
vad_plays_tr, vad_plays_te = split_train_test_proportion(vad_plays)
test_plays = raw_data.loc[raw_data['userId'].isin(te_users)]
test_plays = test_plays.loc[test_plays['movieId'].isin(unique_sid)]
test_plays_tr, test_plays_te = split_train_test_proportion(test_plays)
# Out:
# 0 users sampled
# 1000 users sampled
# 2000 users sampled
# 3000 users sampled
# 4000 users sampled
# 5000 users sampled
# 6000 users sampled
# 7000 users sampled
# 8000 users sampled
# 9000 users sampled
# 0 users sampled
# 1000 users sampled
# 2000 users sampled
# 3000 users sampled
# 4000 users sampled
# 5000 users sampled
# 6000 users sampled
# 7000 users sampled
# 8000 users sampled
# 9000 users sampled

# %%
def numerize(tp):

    uid = [profile2id[x] for x in tp['userId']]

    sid = [show2id[x] for x in tp['movieId']]

    return pd.DataFrame(data={'uid': uid, 'sid': sid}, columns=['uid', 'sid'])


train_data = numerize(train_plays)
train_data.to_csv(os.path.join(pro_dir, 'train.csv'), index=False)

vad_data_tr = numerize(vad_plays_tr)
vad_data_tr.to_csv(os.path.join(pro_dir, 'validation_tr.csv'), index=False)

vad_data_te = numerize(vad_plays_te)
vad_data_te.to_csv(os.path.join(pro_dir, 'validation_te.csv'), index=False)

test_data_tr = numerize(test_plays_tr)
test_data_tr.to_csv(os.path.join(pro_dir, 'test_tr.csv'), index=False)

test_data_te = numerize(test_plays_te)
test_data_te.to_csv(os.path.join(pro_dir, 'test_te.csv'), index=False)

# %%
unique_sid = list()
with open(os.path.join(pro_dir, 'unique_sid.txt'), 'r') as f:
    for line in f:
        unique_sid.append(line.strip())

n_items = len(unique_sid)

# %%
def load_train_data(csv_file):
    tp = pd.read_csv(csv_file)
    n_users = tp['uid'].max() + 1

    rows, cols = tp['uid'], tp['sid']
    data = sparse.csr_matrix((np.ones_like(rows),
                             (rows, cols)), dtype='float64',
                             shape=(n_users, n_items))
    return data

# %%
train_data = load_train_data(os.path.join(pro_dir, 'train.csv'))

# %%
def load_tr_te_data(csv_file_tr, csv_file_te):
    tp_tr = pd.read_csv(csv_file_tr)
    tp_te = pd.read_csv(csv_file_te)

    start_idx = min(tp_tr['uid'].min(), tp_te['uid'].min())
    end_idx = max(tp_tr['uid'].max(), tp_te['uid'].max())

    rows_tr, cols_tr = tp_tr['uid'] - start_idx, tp_tr['sid']
    rows_te, cols_te = tp_te['uid'] - start_idx, tp_te['sid']

    data_tr = sparse.csr_matrix((np.ones_like(rows_tr),
                             (rows_tr, cols_tr)), dtype='float64', shape=(end_idx - start_idx + 1, n_items))
    data_te = sparse.csr_matrix((np.ones_like(rows_te),
                             (rows_te, cols_te)), dtype='float64', shape=(end_idx - start_idx + 1, n_items))
    return data_tr, data_te

# %%
vad_data_tr, vad_data_te = load_tr_te_data(os.path.join(pro_dir, 'validation_tr.csv'),
                                           os.path.join(pro_dir, 'validation_te.csv'))

# %%
N = train_data.shape[0]
idxlist = range(N)

# training batch size
batch_size = 500
batches_per_epoch = int(np.ceil(float(N) / batch_size))

N_vad = vad_data_tr.shape[0]
idxlist_vad = range(N_vad)

# validation batch size (since the entire validation set might not fit into GPU memory)
batch_size_vad = 2000

# the total number of gradient updates for annealing
total_anneal_steps = 200000
# largest annealing parameter
anneal_cap = 0.2

# %% [markdown]
# # Evaluation Metric(s)
#
# In the tests, only NDCG@100 metric is used. `NDCG_binary_at_k_batch` function is taken from [RaCT-CF](https://github.com/samlobel/RaCT_CF/tree/master/utils) repository and modified to work with PyTorch.

# %%
train_data.shape[0] + vad_data_te.shape[0] + vad_data_tr.shape[0]
# Out:
# 136677

# %%
def spy_sparse2torch_sparse(data):
    """

    :param data: a scipy sparse csr matrix
    :return: a sparse torch tensor
    """
    samples=data.shape[0]
    features=data.shape[1]
    values=data.data
    coo_data=data.tocoo()
    indices=torch.LongTensor([coo_data.row,coo_data.col])
    t=torch.sparse.FloatTensor(indices,torch.from_numpy(values).float(),[samples,features])
    return t

# %% [markdown]
# # Tests using our implementation
#
# Below our RaCT implementation is tested. Note that the implementation follows the pseudo-code in the paper.
#
# Pre-training of actor -> Pre-training of critic -> alternative training of both

# %%
from RaCT import RaCT
# Initialize the RaCT algorithm object
ract = RaCT(train_data.shape[1],600,200,600,3,0.01)

# %% [markdown]
# ## Pre-training of Actor
#
# This part seems to more or less work.
#
# We expect to see:
#
# 1. ELBO decreases after 50th(Annealing) epoch.(Until 50,  Beta increases so ELBO may increase too.)
# 2. NLLL should decrease too. Decrease of NLLL indicates that we can better predict&construct the interaction distribution.
# 3. NDCG performance should go as high as 0.4. This is the reported result from the paper.
#
# The results below show that 1 is satisfied whereas 2 and 3 are problematic. NLLL oscillates between 0.01 and 0.02. Although NDCG increase and show a learning performance, it doesn't go above 0.25.

# %%
ract.pretrain_actor(train_data,500,0.2,150,50,vad_data_tr)
# Out:
# NLLL :  tensor(0.0201)
# Elbo :  tensor(0.0201)
# /usr/local/anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:168: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NDCG mean : tensor(0.0073)
# NLLL :  tensor(0.0168)
# Elbo :  tensor(0.0183)
# NLLL :  tensor(0.0168)
# Elbo :  tensor(0.2355)
# NLLL :  tensor(0.0204)
# Elbo :  tensor(0.3640)
# NLLL :  tensor(0.0162)
# Elbo :  tensor(2.4178)
# NLLL :  tensor(0.0206)
# Elbo :  tensor(0.1866)
# NLLL :  tensor(0.0195)
# Elbo :  tensor(1.0939)
# NLLL :  tensor(0.0168)
# Elbo :  tensor(0.4005)
# NLLL :  tensor(0.0204)
# Elbo :  tensor(0.6019)
# NLLL :  tensor(0.0209)
# Elbo :  tensor(1.0105)
# NLLL :  tensor(0.0183)
# Elbo :  tensor(0.2020)
# NLLL :  tensor(0.0196)
# Elbo :  tensor(0.5585)
# NLLL :  tensor(0.0170)
# Elbo :  tensor(0.3699)
# NLLL :  tensor(0.0177)
# Elbo :  tensor(0.4677)
# NLLL :  tensor(0.0163)
# Elbo :  tensor(0.4078)
# NLLL :  tensor(0.0186)
# Elbo :  tensor(0.6348)
# NLLL :  tensor(0.0172)
# Elbo :  tensor(0.3782)
# NLLL :  tensor(0.0177)
# Elbo :  tensor(0.5322)
# NLLL :  tensor(0.0184)
# Elbo :  tensor(0.5639)
# NLLL :  tensor(0.0192)
# Elbo :  tensor(0.4658)
# NLLL :  tensor(0.0183)
# Elbo :  tensor(0.3878)
# NDCG mean : tensor(0.0891)
# NLLL :  tensor(0.0166)
# Elbo :  tensor(0.3491)
# NLLL :  tensor(0.0182)
# Elbo :  tensor(0.3678)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.2917)
# NLLL :  tensor(0.0157)
# Elbo :  tensor(0.2436)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.2261)
# NLLL :  tensor(0.0170)
# Elbo :  tensor(0.2630)
# NLLL :  tensor(0.0158)
# Elbo :  tensor(0.2434)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.2262)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.2172)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.2218)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.1824)
# NLLL :  tensor(0.0168)
# Elbo :  tensor(0.1988)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.1455)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.1425)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.1344)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.1355)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.1460)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.1179)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.1310)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.1166)
# NDCG mean : tensor(0.1486)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.1290)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0990)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.1005)
# NLLL :  tensor(0.0128)
# Elbo :  tensor(0.0860)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0918)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0889)
# NLLL :  tensor(0.0119)
# Elbo :  tensor(0.0723)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0849)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0792)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0768)
# NLLL :  tensor(0.0156)
# Elbo :  tensor(0.0855)
# NLLL :  tensor(0.0156)
# Elbo :  tensor(0.0811)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0712)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.0753)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.0634)
# NLLL :  tensor(0.0163)
# Elbo :  tensor(0.0744)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0728)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0713)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0678)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(0.0707)
# NDCG mean : tensor(0.1884)
# NLLL :  tensor(0.0161)
# Elbo :  tensor(0.0740)
# NLLL :  tensor(0.0157)
# Elbo :  tensor(0.0661)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0612)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0619)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0567)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0556)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0580)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0563)
# NLLL :  tensor(0.0124)
# Elbo :  tensor(0.0508)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0645)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.0590)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0534)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.0506)
# NLLL :  tensor(0.0156)
# Elbo :  tensor(0.0659)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0549)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.0623)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0560)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0544)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0596)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0499)
# NDCG mean : tensor(0.2010)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(0.0602)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0552)
# NLLL :  tensor(0.0128)
# Elbo :  tensor(0.0444)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.0500)
# NLLL :  tensor(0.0128)
# Elbo :  tensor(0.0441)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0457)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0502)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0536)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0461)
# NLLL :  tensor(0.0134)
# Elbo :  tensor(0.0443)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0538)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0491)
# NLLL :  tensor(0.0131)
# Elbo :  tensor(0.0442)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0502)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0464)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0456)
# NLLL :  tensor(0.0162)
# Elbo :  tensor(0.0571)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0438)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.0452)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0436)
# NDCG mean : tensor(0.1984)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.0526)
# NLLL :  tensor(0.0168)
# Elbo :  tensor(0.0542)
# NLLL :  tensor(0.0127)
# Elbo :  tensor(0.0332)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0445)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.0413)
# NLLL :  tensor(0.0120)
# Elbo :  tensor(0.0301)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.0453)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0379)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.0348)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0381)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0340)
# NLLL :  tensor(0.0122)
# Elbo :  tensor(0.0302)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0345)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(0.0396)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0382)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0359)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0315)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0363)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0332)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0315)
# NDCG mean : tensor(0.1994)
# NLLL :  tensor(0.0165)
# Elbo :  tensor(0.0418)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0297)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0336)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.0295)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0285)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0295)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.0312)
# NLLL :  tensor(0.0128)
# Elbo :  tensor(0.0284)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0304)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.0312)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0292)
# NLLL :  tensor(0.0158)
# Elbo :  tensor(0.0310)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0268)
# NLLL :  tensor(0.0126)
# Elbo :  tensor(0.0228)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.0300)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0261)
# NLLL :  tensor(0.0156)
# Elbo :  tensor(0.0293)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0266)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0265)
# NLLL :  tensor(0.0132)
# Elbo :  tensor(0.0236)
# NDCG mean : tensor(0.1993)
# NLLL :  tensor(0.0119)
# Elbo :  tensor(0.0208)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0252)
# NLLL :  tensor(0.0133)
# Elbo :  tensor(0.0241)
# NLLL :  tensor(0.0162)
# Elbo :  tensor(0.0302)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0233)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0257)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0246)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0230)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0270)

# %% [markdown]
# ## Pre-training of Critic
#
# This part works.
#
# We expect to see:
#
# 1. A decrease in MSE Loss.
#
# This is satisfied.

# %%
ract.pretrain_critic(train_data,500,50)
# Out:
# /usr/local/anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:97: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NDCG mean : tensor(0.2195)
# MSE :  tensor(0.0954)
# NDCG mean : tensor(0.2183)
# MSE :  tensor(0.0925)
# NDCG mean : tensor(0.2264)
# MSE :  tensor(0.0834)
# NDCG mean : tensor(0.2349)
# MSE :  tensor(0.0794)
# NDCG mean : tensor(0.2233)
# MSE :  tensor(0.0814)
# NDCG mean : tensor(0.2274)
# MSE :  tensor(0.0746)
# NDCG mean : tensor(0.2186)
# MSE :  tensor(0.0775)
# NDCG mean : tensor(0.2240)
# MSE :  tensor(0.0728)
# NDCG mean : tensor(0.2219)
# MSE :  tensor(0.0709)
# NDCG mean : tensor(0.2328)
# MSE :  tensor(0.0655)
# NDCG mean : tensor(0.2327)
# MSE :  tensor(0.0660)
# NDCG mean : tensor(0.2361)
# MSE :  tensor(0.0626)
# NDCG mean : tensor(0.2284)
# MSE :  tensor(0.0585)
# NDCG mean : tensor(0.2305)
# MSE :  tensor(0.0574)
# NDCG mean : tensor(0.2199)
# MSE :  tensor(0.0591)
# NDCG mean : tensor(0.2242)
# MSE :  tensor(0.0503)
# NDCG mean : tensor(0.2208)
# MSE :  tensor(0.0507)
# NDCG mean : tensor(0.2348)
# MSE :  tensor(0.0460)
# NDCG mean : tensor(0.2381)
# MSE :  tensor(0.0456)
# NDCG mean : tensor(0.2250)
# MSE :  tensor(0.0449)
# NDCG mean : tensor(0.2386)
# MSE :  tensor(0.0422)
# NDCG mean : tensor(0.2241)
# MSE :  tensor(0.0406)
# NDCG mean : tensor(0.2351)
# MSE :  tensor(0.0369)
# NDCG mean : tensor(0.2202)
# MSE :  tensor(0.0358)
# NDCG mean : tensor(0.2152)
# MSE :  tensor(0.0353)
# NDCG mean : tensor(0.2326)
# MSE :  tensor(0.0325)
# NDCG mean : tensor(0.2260)
# MSE :  tensor(0.0302)
# NDCG mean : tensor(0.2276)
# MSE :  tensor(0.0269)
# NDCG mean : tensor(0.2252)
# MSE :  tensor(0.0267)
# NDCG mean : tensor(0.2223)
# MSE :  tensor(0.0253)
# NDCG mean : tensor(0.2289)
# MSE :  tensor(0.0235)
# NDCG mean : tensor(0.2218)
# MSE :  tensor(0.0213)
# NDCG mean : tensor(0.2286)
# MSE :  tensor(0.0236)
# NDCG mean : tensor(0.2256)
# MSE :  tensor(0.0227)
# NDCG mean : tensor(0.2304)
# MSE :  tensor(0.0250)
# NDCG mean : tensor(0.2229)
# MSE :  tensor(0.0198)
# NDCG mean : tensor(0.2331)
# MSE :  tensor(0.0201)
# NDCG mean : tensor(0.2327)
# MSE :  tensor(0.0229)
# NDCG mean : tensor(0.2302)
# MSE :  tensor(0.0226)
# NDCG mean : tensor(0.2262)
# MSE :  tensor(0.0211)
# NDCG mean : tensor(0.2122)
# MSE :  tensor(0.0201)
# NDCG mean : tensor(0.2313)
# MSE :  tensor(0.0198)
# NDCG mean : tensor(0.2194)
# MSE :  tensor(0.0205)
# NDCG mean : tensor(0.2271)
# MSE :  tensor(0.0233)
# NDCG mean : tensor(0.2190)
# MSE :  tensor(0.0205)
# NDCG mean : tensor(0.2165)
# MSE :  tensor(0.0213)
# NDCG mean : tensor(0.2280)
# MSE :  tensor(0.0222)
# NDCG mean : tensor(0.2132)
# MSE :  tensor(0.0209)
# NDCG mean : tensor(0.2352)
# MSE :  tensor(0.0234)
# NDCG mean : tensor(0.2274)
# MSE :  tensor(0.0192)

# %% [markdown]
# ## Alternative Training
#
# This part is problematic.
#
# We expect to see:
#
# 1. A decrease in NLLL, towards 0.
# 2. A decrease in -Critic score.(Note that the reported values are -Critic score, i.e. actor_loss)
# 3. An incrase in NDCG values.
#
# The training is not stable. Sometimes it collapses and we see the opposites of the things above. The results below shows so.
#
# However, the performance can be stable&increasing. It is believed to be dependent on random seed.

# %%
ract.alternative_training(train_data,500,0.2,50)
# Out:
# Critic  0  ,  tensor(-0.2132)
# NLLL :  tensor(0.0163)
# /usr/local/anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:138: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NDCG mean : tensor(0.2234)
# Critic  1  ,  tensor(-0.2131)
# NLLL :  tensor(0.0148)
# NDCG mean : tensor(0.2218)
# Critic  2  ,  tensor(-0.2089)
# NLLL :  tensor(0.0132)
# NDCG mean : tensor(0.1846)
# Critic  3  ,  tensor(-0.2127)
# NLLL :  tensor(0.0125)
# NDCG mean : tensor(0.1795)
# Critic  4  ,  tensor(-0.2142)
# NLLL :  tensor(0.0146)
# NDCG mean : tensor(0.1620)
# Critic  5  ,  tensor(-0.2106)
# NLLL :  tensor(0.0146)
# NDCG mean : tensor(0.1670)
# Critic  6  ,  tensor(-0.2045)
# NLLL :  tensor(0.0133)
# NDCG mean : tensor(0.1630)
# Critic  7  ,  tensor(-0.2042)
# NLLL :  tensor(0.0156)
# NDCG mean : tensor(0.1604)
# Critic  8  ,  tensor(-0.2022)
# NLLL :  tensor(0.0164)
# NDCG mean : tensor(0.1495)
# Critic  9  ,  tensor(-0.1901)
# NLLL :  tensor(0.0191)
# NDCG mean : tensor(0.1477)
# Critic  10  ,  tensor(-0.1881)
# NLLL :  tensor(0.0251)
# NDCG mean : tensor(0.1452)
# Critic  11  ,  tensor(-0.1852)
# NLLL :  tensor(0.0374)
# NDCG mean : tensor(0.1433)
# Critic  12  ,  tensor(-0.1741)
# NLLL :  tensor(0.0458)
# NDCG mean : tensor(0.1487)
# Critic  13  ,  tensor(-0.1816)
# NLLL :  tensor(0.0470)
# NDCG mean : tensor(0.1297)
# Critic  14  ,  tensor(-0.1671)
# NLLL :  tensor(0.0543)
# NDCG mean : tensor(0.1309)
# Critic  15  ,  tensor(-0.1672)
# NLLL :  tensor(0.0535)
# NDCG mean : tensor(0.1171)
# Critic  16  ,  tensor(-0.1698)
# NLLL :  tensor(0.0654)
# NDCG mean : tensor(0.1134)
# Critic  17  ,  tensor(-0.1515)
# NLLL :  tensor(0.0632)
# NDCG mean : tensor(0.1213)
# Critic  18  ,  tensor(-0.1468)
# NLLL :  tensor(0.0837)
# NDCG mean : tensor(0.1191)
# Critic  19  ,  tensor(-0.1452)
# NLLL :  tensor(0.0860)
# NDCG mean : tensor(0.1146)
# Critic  20  ,  tensor(-0.1375)
# NLLL :  tensor(0.0673)
# NDCG mean : tensor(0.1054)
# Critic  21  ,  tensor(-0.1358)
# NLLL :  tensor(0.0575)
# NDCG mean : tensor(0.1001)
# Critic  22  ,  tensor(-0.1282)
# NLLL :  tensor(0.0652)
# NDCG mean : tensor(0.1016)
# Critic  23  ,  tensor(-0.1282)
# NLLL :  tensor(0.0621)
# NDCG mean : tensor(0.0868)
# Critic  24  ,  tensor(-0.1201)
# NLLL :  tensor(0.0607)
# NDCG mean : tensor(0.0910)
# Critic  25  ,  tensor(-0.1189)
# NLLL :  tensor(0.0714)
# NDCG mean : tensor(0.0834)
# Critic  26  ,  tensor(-0.1140)
# NLLL :  tensor(0.0801)
# NDCG mean : tensor(0.0940)
# Critic  27  ,  tensor(-0.1105)
# NLLL :  tensor(0.0827)
# NDCG mean : tensor(0.0840)
# Critic  28  ,  tensor(-0.1067)
# NLLL :  tensor(0.0867)
# NDCG mean : tensor(0.0934)
# Critic  29  ,  tensor(-0.1001)
# NLLL :  tensor(0.0666)
# NDCG mean : tensor(0.0836)
# Critic  30  ,  tensor(-0.0985)
# NLLL :  tensor(0.0962)
# NDCG mean : tensor(0.0807)
# Critic  31  ,  tensor(-0.0947)
# NLLL :  tensor(0.0704)
# NDCG mean : tensor(0.0790)
# Critic  32  ,  tensor(-0.0895)
# NLLL :  tensor(0.0704)
# NDCG mean : tensor(0.0784)
# Critic  33  ,  tensor(-0.0863)
# NLLL :  tensor(0.0829)
# NDCG mean : tensor(0.0847)
# Critic  34  ,  tensor(-0.0806)
# NLLL :  tensor(0.0465)
# NDCG mean : tensor(0.0763)
# Critic  35  ,  tensor(-0.0773)
# NLLL :  tensor(0.0612)
# NDCG mean : tensor(0.0826)
# Critic  36  ,  tensor(-0.0768)
# NLLL :  tensor(0.0753)
# NDCG mean : tensor(0.0823)
# Critic  37  ,  tensor(-0.0755)
# NLLL :  tensor(0.0932)
# NDCG mean : tensor(0.0803)
# Critic  38  ,  tensor(-0.0714)
# NLLL :  tensor(0.0810)
# NDCG mean : tensor(0.0876)
# Critic  39  ,  tensor(-0.0702)
# NLLL :  tensor(0.0665)
# NDCG mean : tensor(0.0842)
# Critic  40  ,  tensor(-0.0719)
# NLLL :  tensor(0.0877)
# NDCG mean : tensor(0.0882)
# Critic  41  ,  tensor(-0.0730)
# NLLL :  tensor(0.1170)
# NDCG mean : tensor(0.0969)
# Critic  42  ,  tensor(-0.0732)
# NLLL :  tensor(0.0822)
# NDCG mean : tensor(0.0993)
# Critic  43  ,  tensor(-0.0738)
# NLLL :  tensor(0.0821)
# NDCG mean : tensor(0.0900)
# Critic  44  ,  tensor(-0.0734)
# NLLL :  tensor(0.0681)
# NDCG mean : tensor(0.0913)
# Critic  45  ,  tensor(-0.0773)
# NLLL :  tensor(0.0944)
# NDCG mean : tensor(0.1090)
# Critic  46  ,  tensor(-0.0786)
# NLLL :  tensor(0.1087)
# NDCG mean : tensor(0.1026)
# Critic  47  ,  tensor(-0.0809)
# NLLL :  tensor(0.0984)
# NDCG mean : tensor(0.1064)
# Critic  48  ,  tensor(-0.0822)
# NLLL :  tensor(0.0812)
# NDCG mean : tensor(0.0917)
# Critic  49  ,  tensor(-0.0854)
# NLLL :  tensor(0.1088)
# NDCG mean : tensor(0.1057)

# %% [markdown]
# ## Result from Stable Case

# %%
from RaCT import RaCT

ract = RaCT(train_data.shape[1],600,200,600,3,0.01)
ract.pretrain_actor(train_data,500,0.2,150,50,vad_data_tr)
ract.pretrain_critic(train_data,500,50)
# Out:
# NLLL :  tensor(0.0172)
# Elbo :  tensor(0.0172)
# /s/chopin/a/grad/atercan/workspace/maml/pytorch_ract/RaCT.py:183: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ndcg = torch.tensor(ndcg.reshape(-1,1),dtype=torch.float32)
# NDCG mean : tensor(0.0069)
# NLLL :  tensor(0.0172)
# Elbo :  tensor(0.0185)
# NLLL :  tensor(0.0163)
# Elbo :  tensor(0.2104)
# NLLL :  tensor(0.0203)
# Elbo :  tensor(0.3037)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(3.1468)
# NLLL :  tensor(0.0186)
# Elbo :  tensor(0.1416)
# NLLL :  tensor(0.0217)
# Elbo :  tensor(1.0518)
# NLLL :  tensor(0.0181)
# Elbo :  tensor(0.2699)
# NLLL :  tensor(0.0201)
# Elbo :  tensor(1.7373)
# NLLL :  tensor(0.0182)
# Elbo :  tensor(0.6741)
# NLLL :  tensor(0.0184)
# Elbo :  tensor(0.5111)
# NLLL :  tensor(0.0184)
# Elbo :  tensor(0.9967)
# NLLL :  tensor(0.0169)
# Elbo :  tensor(0.4408)
# NLLL :  tensor(0.0171)
# Elbo :  tensor(0.5412)
# NLLL :  tensor(0.0194)
# Elbo :  tensor(0.9130)
# NLLL :  tensor(0.0171)
# Elbo :  tensor(0.3875)
# NLLL :  tensor(0.0171)
# Elbo :  tensor(0.5539)
# NLLL :  tensor(0.0159)
# Elbo :  tensor(0.5763)
# NLLL :  tensor(0.0170)
# Elbo :  tensor(0.5997)
# NLLL :  tensor(0.0170)
# Elbo :  tensor(0.4496)
# NLLL :  tensor(0.0158)
# Elbo :  tensor(0.5529)
# NDCG mean : tensor(0.0945)
# NLLL :  tensor(0.0165)
# Elbo :  tensor(0.4524)
# NLLL :  tensor(0.0166)
# Elbo :  tensor(0.3224)
# NLLL :  tensor(0.0159)
# Elbo :  tensor(1.5195)
# NLLL :  tensor(0.0172)
# Elbo :  tensor(0.5252)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.4157)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.3475)
# NLLL :  tensor(0.0157)
# Elbo :  tensor(0.3178)
# NLLL :  tensor(0.0172)
# Elbo :  tensor(0.3233)
# NLLL :  tensor(0.0150)
# Elbo :  tensor(0.2362)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.2580)
# NLLL :  tensor(0.0164)
# Elbo :  tensor(0.3046)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.2462)
# NLLL :  tensor(0.0163)
# Elbo :  tensor(0.3456)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.2703)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.2671)
# NLLL :  tensor(0.0158)
# Elbo :  tensor(0.2840)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.3389)
# NLLL :  tensor(0.0131)
# Elbo :  tensor(0.2429)
# NLLL :  tensor(0.0131)
# Elbo :  tensor(0.2330)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.2558)
# NDCG mean : tensor(0.1587)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.2738)
# NLLL :  tensor(0.0126)
# Elbo :  tensor(0.2250)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.2263)
# NLLL :  tensor(0.0125)
# Elbo :  tensor(0.1978)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.2370)
# NLLL :  tensor(0.0164)
# Elbo :  tensor(0.2397)
# NLLL :  tensor(0.0158)
# Elbo :  tensor(0.2416)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.2475)
# NLLL :  tensor(0.0162)
# Elbo :  tensor(0.2436)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.2324)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.1805)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.2006)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.1799)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.1679)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.1631)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.1613)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.1352)
# NLLL :  tensor(0.0150)
# Elbo :  tensor(0.1365)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.1235)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.1323)
# NDCG mean : tensor(0.1839)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.1015)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.1118)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0993)
# NLLL :  tensor(0.0122)
# Elbo :  tensor(0.0796)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0958)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0810)
# NLLL :  tensor(0.0125)
# Elbo :  tensor(0.0707)
# NLLL :  tensor(0.0136)
# Elbo :  tensor(0.0759)
# NLLL :  tensor(0.0169)
# Elbo :  tensor(0.0908)
# NLLL :  tensor(0.0170)
# Elbo :  tensor(0.0881)
# NLLL :  tensor(0.0119)
# Elbo :  tensor(0.0576)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0731)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0674)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0657)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0604)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0646)
# NLLL :  tensor(0.0152)
# Elbo :  tensor(0.0641)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.0671)
# NLLL :  tensor(0.0134)
# Elbo :  tensor(0.0532)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.0604)
# NDCG mean : tensor(0.1947)
# NLLL :  tensor(0.0133)
# Elbo :  tensor(0.0575)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0547)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.0564)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.0545)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0563)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0555)
# NLLL :  tensor(0.0131)
# Elbo :  tensor(0.0524)
# NLLL :  tensor(0.0159)
# Elbo :  tensor(0.0657)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0585)
# NLLL :  tensor(0.0154)
# Elbo :  tensor(0.0584)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.0459)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0506)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0481)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0486)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.0513)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.0466)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.0512)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0487)
# NLLL :  tensor(0.0159)
# Elbo :  tensor(0.0631)
# NLLL :  tensor(0.0150)
# Elbo :  tensor(0.0507)
# NDCG mean : tensor(0.1964)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0537)
# NLLL :  tensor(0.0123)
# Elbo :  tensor(0.0393)
# NLLL :  tensor(0.0150)
# Elbo :  tensor(0.0579)
# NLLL :  tensor(0.0134)
# Elbo :  tensor(0.0410)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0541)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0462)
# NLLL :  tensor(0.0129)
# Elbo :  tensor(0.0433)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(0.0555)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0459)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0515)
# NLLL :  tensor(0.0153)
# Elbo :  tensor(0.0439)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0433)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0409)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0448)
# NLLL :  tensor(0.0137)
# Elbo :  tensor(0.0414)
# NLLL :  tensor(0.0132)
# Elbo :  tensor(0.0361)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0411)
# NLLL :  tensor(0.0129)
# Elbo :  tensor(0.0351)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0388)
# NLLL :  tensor(0.0124)
# Elbo :  tensor(0.0341)
# NDCG mean : tensor(0.2020)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0399)
# NLLL :  tensor(0.0155)
# Elbo :  tensor(0.0382)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0385)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0343)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.0330)
# NLLL :  tensor(0.0151)
# Elbo :  tensor(0.0410)
# NLLL :  tensor(0.0150)
# Elbo :  tensor(0.0446)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0371)
# NLLL :  tensor(0.0141)
# Elbo :  tensor(0.0403)
# NLLL :  tensor(0.0160)
# Elbo :  tensor(0.0397)
# NLLL :  tensor(0.0132)
# Elbo :  tensor(0.0362)
# NLLL :  tensor(0.0144)
# Elbo :  tensor(0.0355)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0362)
# NLLL :  tensor(0.0156)
# Elbo :  tensor(0.0420)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0342)
# NLLL :  tensor(0.0149)
# Elbo :  tensor(0.0359)
# NLLL :  tensor(0.0139)
# Elbo :  tensor(0.0325)
# NLLL :  tensor(0.0140)
# Elbo :  tensor(0.0334)
# NLLL :  tensor(0.0143)
# Elbo :  tensor(0.0334)
# NLLL :  tensor(0.0142)
# Elbo :  tensor(0.0328)
# NDCG mean : tensor(0.2065)
# NLLL :  tensor(0.0161)
# Elbo :  tensor(0.0371)
# NLLL :  tensor(0.0146)
# Elbo :  tensor(0.0363)
# NLLL :  tensor(0.0138)
# Elbo :  tensor(0.0306)
# NLLL :  tensor(0.0148)
# Elbo :  tensor(0.0342)
# NLLL :  tensor(0.0130)
# Elbo :  tensor(0.0294)
# NLLL :  tensor(0.0147)
# Elbo :  tensor(0.0330)
# NLLL :  tensor(0.0135)
# Elbo :  tensor(0.0329)
# NLLL :  tensor(0.0162)
# Elbo :  tensor(0.0384)
# NLLL :  tensor(0.0145)
# Elbo :  tensor(0.0328)
# /s/chopin/a/grad/atercan/workspace/maml/pytorch_ract/RaCT.py:97: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ndcg = torch.tensor(ndcg.reshape(-1,1),dtype=torch.float32)
# NDCG mean : tensor(0.2324)
# MSE :  tensor(0.1292)
# NDCG mean : tensor(0.2239)
# MSE :  tensor(0.1328)
# NDCG mean : tensor(0.2242)
# MSE :  tensor(0.1281)
# NDCG mean : tensor(0.2235)
# MSE :  tensor(0.1233)
# NDCG mean : tensor(0.2262)
# MSE :  tensor(0.1213)
# NDCG mean : tensor(0.2335)
# MSE :  tensor(0.1154)
# NDCG mean : tensor(0.2311)
# MSE :  tensor(0.1108)
# NDCG mean : tensor(0.2234)
# MSE :  tensor(0.1114)
# NDCG mean : tensor(0.2303)
# MSE :  tensor(0.0974)
# NDCG mean : tensor(0.2168)
# MSE :  tensor(0.1041)
# NDCG mean : tensor(0.2324)
# MSE :  tensor(0.0950)
# NDCG mean : tensor(0.2243)
# MSE :  tensor(0.0996)
# NDCG mean : tensor(0.2238)
# MSE :  tensor(0.0902)
# NDCG mean : tensor(0.2293)
# MSE :  tensor(0.0846)
# NDCG mean : tensor(0.2317)
# MSE :  tensor(0.0756)
# NDCG mean : tensor(0.2222)
# MSE :  tensor(0.0738)
# NDCG mean : tensor(0.2264)
# MSE :  tensor(0.0701)
# NDCG mean : tensor(0.2125)
# MSE :  tensor(0.0685)
# NDCG mean : tensor(0.2288)
# MSE :  tensor(0.0606)
# NDCG mean : tensor(0.2213)
# MSE :  tensor(0.0606)
# NDCG mean : tensor(0.2298)
# MSE :  tensor(0.0506)
# NDCG mean : tensor(0.2184)
# MSE :  tensor(0.0543)
# NDCG mean : tensor(0.2301)
# MSE :  tensor(0.0428)
# NDCG mean : tensor(0.2236)
# MSE :  tensor(0.0438)
# NDCG mean : tensor(0.2315)
# MSE :  tensor(0.0355)
# NDCG mean : tensor(0.2289)
# MSE :  tensor(0.0381)
# NDCG mean : tensor(0.2160)
# MSE :  tensor(0.0347)
# NDCG mean : tensor(0.2265)
# MSE :  tensor(0.0304)
# NDCG mean : tensor(0.2284)
# MSE :  tensor(0.0286)
# NDCG mean : tensor(0.2262)
# MSE :  tensor(0.0283)
# NDCG mean : tensor(0.2281)
# MSE :  tensor(0.0249)
# NDCG mean : tensor(0.2204)
# MSE :  tensor(0.0259)
# NDCG mean : tensor(0.2210)
# MSE :  tensor(0.0266)
# NDCG mean : tensor(0.2260)
# MSE :  tensor(0.0241)
# NDCG mean : tensor(0.2188)
# MSE :  tensor(0.0252)
# NDCG mean : tensor(0.2315)
# MSE :  tensor(0.0250)
# NDCG mean : tensor(0.2180)
# MSE :  tensor(0.0219)
# NDCG mean : tensor(0.2272)
# MSE :  tensor(0.0247)
# NDCG mean : tensor(0.2276)
# MSE :  tensor(0.0257)
# NDCG mean : tensor(0.2295)
# MSE :  tensor(0.0228)
# NDCG mean : tensor(0.2326)
# MSE :  tensor(0.0240)
# NDCG mean : tensor(0.2260)
# MSE :  tensor(0.0242)
# NDCG mean : tensor(0.2249)
# MSE :  tensor(0.0225)
# NDCG mean : tensor(0.2228)
# MSE :  tensor(0.0232)
# NDCG mean : tensor(0.2262)
# MSE :  tensor(0.0228)
# NDCG mean : tensor(0.2222)
# MSE :  tensor(0.0200)
# NDCG mean : tensor(0.2328)
# MSE :  tensor(0.0230)
# NDCG mean : tensor(0.2299)
# MSE :  tensor(0.0206)
# NDCG mean : tensor(0.2279)
# MSE :  tensor(0.0213)
# NDCG mean : tensor(0.2184)
# MSE :  tensor(0.0187)

# %%
ract.alternative_training(train_data,500,0.2,50)
# Out:
# /usr/local/anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:193: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch  0  ,  tensor(-0.3131)
# NLLL :  tensor(0.0257)
# /usr/local/anaconda-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# NDCG mean : tensor(0.2548)
# tensor(0.1433)
# Epoch  1  ,  tensor(-0.3335)
# NLLL :  tensor(0.0297)
# NDCG mean : tensor(0.2487)
# tensor(0.1393)
# Epoch  2  ,  tensor(-0.3503)
# NLLL :  tensor(0.0320)
# NDCG mean : tensor(0.2388)
# tensor(0.1535)
# Epoch  3  ,  tensor(-0.3211)
# NLLL :  tensor(0.0287)
# NDCG mean : tensor(0.2373)
# tensor(0.1447)
# Epoch  4  ,  tensor(-0.3057)
# NLLL :  tensor(0.0308)
# NDCG mean : tensor(0.2329)
# tensor(0.1425)
# Epoch  5  ,  tensor(-0.2846)
# NLLL :  tensor(0.0302)
# NDCG mean : tensor(0.2169)
# tensor(0.1283)
# Epoch  6  ,  tensor(-0.2937)
# NLLL :  tensor(0.0279)
# NDCG mean : tensor(0.2103)
# tensor(0.1268)
# Epoch  7  ,  tensor(-0.2965)
# NLLL :  tensor(0.0298)
# NDCG mean : tensor(0.2031)
# tensor(0.1399)
# Epoch  8  ,  tensor(-0.2809)
# NLLL :  tensor(0.0306)
# NDCG mean : tensor(0.1986)
# tensor(0.1233)
# Epoch  9  ,  tensor(-0.2773)
# NLLL :  tensor(0.0283)
# NDCG mean : tensor(0.2056)
# tensor(0.1222)
# Epoch  10  ,  tensor(-0.2553)
# NLLL :  tensor(0.0295)
# NDCG mean : tensor(0.1926)
# tensor(0.1195)
# Epoch  11  ,  tensor(-0.2427)
# NLLL :  tensor(0.0275)
# NDCG mean : tensor(0.1915)
# tensor(0.1223)
# Epoch  12  ,  tensor(-0.2577)
# NLLL :  tensor(0.0302)
# NDCG mean : tensor(0.1983)
# tensor(0.1249)
# Epoch  13  ,  tensor(-0.2241)
# NLLL :  tensor(0.0285)
# NDCG mean : tensor(0.2060)
# tensor(0.1106)
# Epoch  14  ,  tensor(-0.1834)
# NLLL :  tensor(0.0264)
# NDCG mean : tensor(0.1908)
# tensor(0.0928)
# Epoch  15  ,  tensor(-0.2049)
# NLLL :  tensor(0.0284)
# NDCG mean : tensor(0.2068)
# tensor(0.1009)
# Epoch  16  ,  tensor(-0.1768)
# NLLL :  tensor(0.0274)
# NDCG mean : tensor(0.1927)
# tensor(0.1086)
# Epoch  17  ,  tensor(-0.1633)
# NLLL :  tensor(0.0316)
# NDCG mean : tensor(0.2037)
# tensor(0.1042)
# Epoch  18  ,  tensor(-0.1514)
# NLLL :  tensor(0.0294)
# NDCG mean : tensor(0.2121)
# tensor(0.0866)
# Epoch  19  ,  tensor(-0.1376)
# NLLL :  tensor(0.0298)
# NDCG mean : tensor(0.2118)
# tensor(0.0975)
# Epoch  20  ,  tensor(-0.1398)
# NLLL :  tensor(0.0320)
# NDCG mean : tensor(0.2134)
# tensor(0.1031)
# Epoch  21  ,  tensor(-0.1126)
# NLLL :  tensor(0.0277)
# NDCG mean : tensor(0.2233)
# tensor(0.0913)
# Epoch  22  ,  tensor(-0.1173)
# NLLL :  tensor(0.0312)
# NDCG mean : tensor(0.2200)
# tensor(0.0967)
# Epoch  23  ,  tensor(-0.0739)
# NLLL :  tensor(0.0265)
# NDCG mean : tensor(0.2296)
# tensor(0.1027)
# Epoch  24  ,  tensor(-0.0768)
# NLLL :  tensor(0.0294)
# NDCG mean : tensor(0.2176)
# tensor(0.0976)
# Epoch  25  ,  tensor(-0.0682)
# NLLL :  tensor(0.0291)
# NDCG mean : tensor(0.2109)
# tensor(0.0903)
# Epoch  26  ,  tensor(-0.0622)
# NLLL :  tensor(0.0306)
# NDCG mean : tensor(0.2262)
# tensor(0.1031)
# Epoch  27  ,  tensor(-0.0336)
# NLLL :  tensor(0.0265)
# NDCG mean : tensor(0.2222)
# tensor(0.0987)
# Epoch  28  ,  tensor(-0.0583)
# NLLL :  tensor(0.0299)
# NDCG mean : tensor(0.2261)
# tensor(0.1004)
# Epoch  29  ,  tensor(-0.0249)
# NLLL :  tensor(0.0259)
# NDCG mean : tensor(0.2285)
# tensor(0.1057)
# Epoch  30  ,  tensor(-0.0462)
# NLLL :  tensor(0.0318)
# NDCG mean : tensor(0.2334)
# tensor(0.1032)
# Epoch  31  ,  tensor(-0.0436)
# NLLL :  tensor(0.0306)
# NDCG mean : tensor(0.2318)
# tensor(0.1063)
# Epoch  32  ,  tensor(-0.0393)
# NLLL :  tensor(0.0309)
# NDCG mean : tensor(0.2355)
# tensor(0.1016)
# Epoch  33  ,  tensor(-0.0428)
# NLLL :  tensor(0.0311)
# NDCG mean : tensor(0.2248)
# tensor(0.1011)
# Epoch  34  ,  tensor(-0.0479)
# NLLL :  tensor(0.0272)
# NDCG mean : tensor(0.2450)
# tensor(0.1075)
# Epoch  35  ,  tensor(-0.0508)
# NLLL :  tensor(0.0261)
# NDCG mean : tensor(0.2327)
# tensor(0.0966)
# Epoch  36  ,  tensor(-0.0719)
# NLLL :  tensor(0.0296)
# NDCG mean : tensor(0.2262)
# tensor(0.0943)
# Epoch  37  ,  tensor(-0.0823)
# NLLL :  tensor(0.0293)
# NDCG mean : tensor(0.2351)
# tensor(0.0955)
# Epoch  38  ,  tensor(-0.0782)
# NLLL :  tensor(0.0296)
# NDCG mean : tensor(0.2338)
# tensor(0.0966)
# Epoch  39  ,  tensor(-0.1173)
# NLLL :  tensor(0.0309)
# NDCG mean : tensor(0.2442)
# tensor(0.1086)
# Epoch  40  ,  tensor(-0.0995)
# NLLL :  tensor(0.0290)
# NDCG mean : tensor(0.2313)
# tensor(0.0933)
# Epoch  41  ,  tensor(-0.1423)
# NLLL :  tensor(0.0337)
# NDCG mean : tensor(0.2476)
# tensor(0.1099)
# Epoch  42  ,  tensor(-0.1159)
# NLLL :  tensor(0.0283)
# NDCG mean : tensor(0.2458)
# tensor(0.1032)
# Epoch  43  ,  tensor(-0.1089)
# NLLL :  tensor(0.0273)
# NDCG mean : tensor(0.2375)
# tensor(0.0944)
# Epoch  44  ,  tensor(-0.1261)
# NLLL :  tensor(0.0286)
# NDCG mean : tensor(0.2503)
# tensor(0.1037)
# Epoch  45  ,  tensor(-0.1187)
# NLLL :  tensor(0.0282)
# NDCG mean : tensor(0.2435)
# tensor(0.1045)
# Epoch  46  ,  tensor(-0.1294)
# NLLL :  tensor(0.0287)
# NDCG mean : tensor(0.2464)
# tensor(0.1039)
# Epoch  47  ,  tensor(-0.1370)
# NLLL :  tensor(0.0304)
# NDCG mean : tensor(0.2408)
# tensor(0.0996)
# Epoch  48  ,  tensor(-0.1268)
# NLLL :  tensor(0.0323)
# NDCG mean : tensor(0.2354)
# tensor(0.0992)
# Epoch  49  ,  tensor(-0.1358)
# NLLL :  tensor(0.0330)
# NDCG mean : tensor(0.2470)
# tensor(0.1106)
